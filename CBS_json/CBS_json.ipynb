# %%
import pandas as pd
# Dependencies
import requests
import json

# %%
CBS_total=pd.read_csv("data/CBS_totals.csv")
CBS_total
# Out:
#      Unnamed: 0  station_id        lat        lng  \
# 0             0       31000  38.858971 -77.053230
# 1             1       31001  38.857250 -77.053320
# 2             2       31002  38.856425 -77.049232
# 3             3       31003  38.860170 -77.049593
# 4             4       31004  38.857880 -77.059505
# ..          ...         ...        ...        ...
# 605         605       32606  38.878085 -77.153953
# 606         606       32607  38.879773 -77.178394
# 607         607       32608  38.885379 -77.173522
# 608         608       32609  38.885621 -77.166917
# 609         609       32901  38.963810 -77.010266
#
#                                                address  trips_2010  \
# 0                                  Eads St & 15th St S         185
# 1                                  18th St & S Eads St         372
# 2                               Crystal Dr & 20th St S         362
# 3                               Crystal Dr & 15th St S         463
# ...

# %%
CBS_total=CBS_total.rename(columns={"Unnamed: 0": "index"})
CBS_total.head()
# Out:
#    index  station_id        lat        lng  \
# 0      0       31000  38.858971 -77.053230
# 1      1       31001  38.857250 -77.053320
# 2      2       31002  38.856425 -77.049232
# 3      3       31003  38.860170 -77.049593
# 4      4       31004  38.857880 -77.059505
#
#                                         address  trips_2010  trips_2011  \
# 0                           Eads St & 15th St S         185        1171
# 1                           18th St & S Eads St         372        3492
# 2                        Crystal Dr & 20th St S         362        2883
# 3                        Crystal Dr & 15th St S         463        3432
# 4  Aurora Hills Cmty Ctr / 18th St & S Hayes St         234        1598
#
#    trips_2012  trips_2013  trips_2014  trips_2015  trips_2016  trips_2017  \
# 0        1353        1128        1247        1891        1883        2529
# 1        3393        2345        2180        2768        2233        2428
# ...

# %%
CBS_total.to_json("data/CBS_total.json", orient='records')
